# %% [markdown]
# <a href="https://colab.research.google.com/github/tanlull/Heart-Equation/blob/master/Heart_Equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **สมการหัวใจ**
#
# ![alt text](https://cdn-images-1.medium.com/max/750/1*kL4yCCVA17bSd3GC1I3WIA.png
# )

# %%
t = np.arange(0,2*np.pi, 0.1)
x = 16*np.sin(t)**3
y = 13*np.cos(t)-5*np.cos(2*t)-2*np.cos(3*t)-np.cos(4*t)
plt.grid(False)
plt.axis('off')
plt.plot(x,y,'r-')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
#  # **สมการหัวใจ 3 มิติ**
#
# ![alt text](https://cdn-images-1.medium.com/max/1000/1*g3A17Zh4trnxmdnyiyZxtw.png)

# %%
from mpl_toolkits.mplot3d import Axes3D
from skimage import measure
from matplotlib import cm

n = 100 

x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
z = np.linspace(-3,3,n)
X, Y, Z =  np.meshgrid(x, y, z)

def f_heart(x,y,z):
    F = 320 * ((-x**2 * z**3 -9*y**2 * z**3/80) + (x**2 + 9*y**2/4 + z**2-1)**3)
    return F

vol = f_heart(X,Y,Z) 
verts, faces ,_ ,_ = measure.marching_cubes_lewiner(vol, 0, spacing=(0.1, 0.1, 0.1))
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_trisurf(verts[:, 0], verts[:,1], faces, verts[:, 2],cmap=cm.Reds,edgecolor='white')
ax.view_init(15, -15)
ax.grid(False)
plt.axis('off')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ![alt text](https://t0.blockdit.com/photos/2019/02/5c63c071c7269502de5cc02a.jpg)

# %%
x = np.linspace(0,9,100)
y = 1/x
plt.grid(False)
plt.axis('off')
plt.plot(x,y,'r-')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide

# %%
r = 9
x = np.linspace(-r,r,100)
y = np.sqrt(-x**2+r**2)
plt.plot(x, y,'r-')
plt.plot(x,-y,'r-')
plt.gca().set_aspect('equal')
plt.grid(False)
plt.axis('off')
plt.show()

# %%
x = np.linspace(-9,9,100)
y = np.abs(-1*2*x)
plt.plot(x, y,'r-')
plt.gca().set_aspect('equal')
plt.grid(False)
plt.axis('off')
plt.show()

# %%
y = np.linspace(0,6.2,100)
x = -3 * np.abs(np.sin(y))
plt.plot(x, y,'r-')
plt.gca().set_aspect('equal')
plt.grid(False)
plt.axis('off')
plt.show()
